# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/2018_05_25_TaubateMissing.csv', index_col = 'TAUBATE')

# %%
df = df[:-1]

# %%
df.head()
# Out:
#          Maximum Absolute Temperature  Maximum Average Temperature  \
# TAUBATE
# Jan                              36.7                         30.2
# Feb                              40.1                         30.5
# Mar                              36.2                         29.9
# Apr                              34.2                          NaN
# May                              32.6                         25.4
#
#          Average Temperature  Minimum Average Temperature  \
# TAUBATE
# Jan                     23.3                         17.7
# Feb                     23.5                         17.8
# Mar                     22.9                         17.8
# Apr                     20.8                         16.1
# May                     18.1                         14.2
#
#          Minimum Absolute Temperature  Rainfall (mm)  \
# TAUBATE
# Jan                              10.9          233.5
# Feb                              12.6          192.1
# ...

# %%
plt.figure(figsize = (16,8))
plt.xticks([i for i in range(len(df))])


df['Sunshine Hours'].plot()
df['Rainfall (mm)'].plot()

# %%
plt.figure(figsize = (16, 8))
plt.plot(df.index, df['Sunshine Hours'])
