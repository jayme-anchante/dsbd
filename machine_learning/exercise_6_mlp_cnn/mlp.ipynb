# %%
# %matplotlib inline
import numpy as np
import pandas
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.datasets import load_svmlight_file
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
X_train, y_train = load_svmlight_file('mlp_train.txt.bz2')
X_test, y_test = load_svmlight_file('mlp_test.txt.bz2')

# %%
## save for the confusion matrix
label = y_test.copy()

# %%
## converts the labels to a categorical one-hot-vector
y_train = keras.utils.to_categorical(y_train, num_classes=2)
y_test = keras.utils.to_categorical(y_test, num_classes=2)

# %% [markdown]
# # 1 hidden layer

# %%
model = Sequential()
# Dense(50) is a fully-connected layer with 50 hidden units.
# in the first layer, you must specify the expected input data shape:
# here, 100-dimensional vectors.
model.add(Dense(100, activation='relu', input_dim=200))
#model.add(Dense(100, activation='relu', input_dim=200))
model.add(Dense(2, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_split=0.33, epochs=200, batch_size=128)
# Out:
# Train on 16750 samples, validate on 8250 samples
# Epoch 1/200
# 16750/16750 [==============================] - 1s 45us/step - loss: 0.4314 - acc: 0.8099 - val_loss: 0.3470 - val_acc: 0.8550
# Epoch 2/200
# 16750/16750 [==============================] - 1s 34us/step - loss: 0.3447 - acc: 0.8503 - val_loss: 0.3249 - val_acc: 0.8641
# Epoch 3/200
# 16750/16750 [==============================] - 1s 35us/step - loss: 0.3288 - acc: 0.8554 - val_loss: 0.3159 - val_acc: 0.8681
# Epoch 4/200
# 16750/16750 [==============================] - 1s 34us/step - loss: 0.3172 - acc: 0.8646 - val_loss: 0.3322 - val_acc: 0.8549
# Epoch 5/200
# 16750/16750 [==============================] - 1s 33us/step - loss: 0.3110 - acc: 0.8655 - val_loss: 0.3167 - val_acc: 0.8656
# Epoch 6/200
# 16750/16750 [==============================] - 1s 33us/step - loss: 0.3065 - acc: 0.8693 - val_loss: 0.3034 - val_acc: 0.8710
# Epoch 7/200
# ...

# %%
score = model.evaluate(X_test, y_test, batch_size=128)
print(score)
# Out:
# 25000/25000 [==============================] - 0s 16us/step
# [0.8016464678192139, 0.848119999961853]

# %%
y_pred = model.predict_classes(X_test)
cm = confusion_matrix(label, y_pred)
print(cm)
# Out:
# [[10662  1838]
#  [ 1959 10541]]

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.figure(figsize=(16, 8))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %% [markdown]
# # 2 hidden layers

# %%
model = Sequential()
# Dense(50) is a fully-connected layer with 50 hidden units.
# in the first layer, you must specify the expected input data shape:
# here, 100-dimensional vectors.
model.add(Dense(100, activation='relu', input_dim=200))
model.add(Dense(100, activation='relu', input_dim=200))
model.add(Dense(2, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_split=0.33, epochs=200, batch_size=128)
# Out:
# Train on 16750 samples, validate on 8250 samples
# Epoch 1/200
# 16750/16750 [==============================] - 1s 53us/step - loss: 0.4188 - acc: 0.8064 - val_loss: 0.3760 - val_acc: 0.8248
# Epoch 2/200
# 16750/16750 [==============================] - 1s 35us/step - loss: 0.3434 - acc: 0.8527 - val_loss: 0.3389 - val_acc: 0.8495
# Epoch 3/200
# 16750/16750 [==============================] - 1s 36us/step - loss: 0.3276 - acc: 0.8581 - val_loss: 0.3095 - val_acc: 0.8695
# Epoch 4/200
# 16750/16750 [==============================] - 1s 36us/step - loss: 0.3126 - acc: 0.8661 - val_loss: 0.3371 - val_acc: 0.8558
# Epoch 5/200
# 16750/16750 [==============================] - 1s 36us/step - loss: 0.3067 - acc: 0.8682 - val_loss: 0.3048 - val_acc: 0.8704
# Epoch 6/200
# 16750/16750 [==============================] - 1s 36us/step - loss: 0.2981 - acc: 0.8724 - val_loss: 0.3187 - val_acc: 0.8625
# Epoch 7/200
# ...

# %%
score = model.evaluate(X_test, y_test, batch_size=128)
print(score)
# Out:
# 25000/25000 [==============================] - 0s 16us/step
# [1.5852870752716064, 0.8395599999809266]

# %%
y_pred = model.predict_classes(X_test)
cm = confusion_matrix(label, y_pred)
print(cm)
# Out:
# [[10521  1979]
#  [ 2032 10468]]

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.figure(figsize=(16, 8))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %% [markdown]
# * 1) Cada camada das redes neurais artificiais tem 100 neurônios
# * 2) No primeiro modelo, temos uma camada escondida, enquanto no segundo modelo temos duas camadas escondidas
# * 3) Cada rede neural artificial é treinada com 200 épocas
# * 4) A arquitetura mais complexa (com duas camadas escondidas) entra em overfit mais facilmente, chegando a quase 100% de acurácia nos dados de treinamento, apesar do escore de validação e de teste ficar mais ou menos igual em ambas as arquiteturas
